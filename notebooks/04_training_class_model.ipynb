# %% [markdown]
# ## Training a classification model

# %%
import pandas as pd
import os
import sys
sys.path.insert(0, "../")

from src.training_models.classification_models import ClassificationModel
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load generated dataset

# %%
type_encoder = "FFT"
encoder = "ROBB760113"
df_data = pd.read_csv(f"../results/encoders/{type_encoder}/{encoder}/coded_dataset.csv")
df_data.head(5)
# Out:
#     p_0        p_1        p_2        p_3        p_4        p_5        p_6  \
# 0  64.1  22.175091  43.693286  38.504092  39.118402  77.167023  28.008691
# 1  55.2  16.055970  45.413579  32.944683  46.157438  85.824058  30.251491
# 2  64.4  22.413842  43.665732  38.713232  38.894420  76.876179  27.979319
# 3  59.0  18.792245  43.925460  35.720465  41.988932  82.266677  30.514928
# 4  61.4  20.146252  43.897084  36.520834  41.356719  79.717339  28.013797
#
#          p_7        p_8        p_9  ...      p_247      p_248       p_249  \
# 0  55.400383  47.611109  48.412095  ...  28.262232  66.092433   90.517856
# 1  53.812081  54.141248  42.392005  ...  31.085895  74.991063   97.390389
# 2  55.478009  47.404433  48.630416  ...  28.211080  65.792486   90.292368
# 3  53.509627  54.452357  40.370321  ...  69.155473  57.266000   26.171629
# 4  55.236349  49.916712  46.024327  ...  34.108945  79.956868  101.091252
#
#        p_250      p_251      p_252      p_253      p_254      p_255  \
# ...

# %%
responses = df_data["monomer_state"].values
df_data = df_data.drop(columns=["monomer_state"])

# %%
train_data, validation_data, train_response, validation_response = train_test_split(df_data, responses, random_state=42, test_size=.30)

# %% [markdown]
# ### Training model

# %%
folder_export = f"../results/performance/{type_encoder}/{encoder}"
os.makedirs(folder_export, exist_ok=True)
name_export = f"{folder_export}/results_exploration.csv"

model_instance = ClassificationModel(
    train_values = train_data,
    train_response = train_response,
    test_values = validation_data,
    test_response = validation_response,
    folder_export = folder_export
)

df_exploration = model_instance.apply_exploring()
df_exploration.to_csv(name_export, index=False)
