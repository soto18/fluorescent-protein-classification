# %%
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.insert(0, "../")
from src.processing_tuning_results.performance_processor import PerformanceProcessor
from src.processing_tuning_results.get_plot import PerformanceMergerAndPlotter

# %% [markdown]
# #### Concatenate results

# %%
processor = PerformanceProcessor(
    path_results="../results/tuning/",
    path_export="../results/summary_tuning/"
)
processor.run()
# Out:
# Processing encoder: embedding
# Processing encoder: FFT
# Processing encoder: physicochemical_properties
# Data exported to: ../results/summary_tuning/explored_data.csv

# %% [markdown]
# #### Performance plots

# %%
input_path = "../results/summary_tuning"
output_path = "../results/summary_tuning/"
input_file = "explored_data.csv"
output_file = "processed_tuning.csv"

processor = PerformanceMergerAndPlotter(input_path=input_path, output_path=output_path)
processor.run(input_file, output_file)
# Out:
# Data loaded from ../results/summary_tuning/explored_data.csv
# Processed data saved to ../results/summary_tuning//processed_tuning.csv
# Plotting data...
# Plots generated.
